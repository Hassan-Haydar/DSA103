# %% [markdown]
# ## EDA: iris dataset - part 1: Basic exploration

# %% [markdown]
# ### Preparations
#
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1) Load iris dataset as iris:

# %%
# Load the iris dataset
iris = pd.read_csv(r"/Users/hassanhaydar/DSA103/EDA-lectures-7-8/src/lecture_7/DSA_iris_dataset.csv")
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal l. / cm  petal w. / cm  target  \
# 0                5.1               3.5            1.4            0.2     NaN
# 1                4.9               3.0            1.4            0.2     NaN
# 2                4.7               3.2            1.3            0.2     NaN
# 3                4.6               3.1            1.5            0.2     NaN
# 4                5.0               3.6            1.4            0.2     NaN
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# 2) Overview: head, size, shape, info...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal l. / cm      150 non-null    float64
#  3   petal w. / cm      150 non-null    float64
#  4   target             0 non-null      float64
#  5   species            150 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# 3) Quick statistics and summary (value_counts, max, min, describe, nlargest, nsmallest, nunique):

# %%
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal l. / cm  petal w. / cm  \
# count         150.000000        150.000000     150.000000     150.000000
# mean            5.843333          3.309333       3.758000       1.199333
# std             0.828066          3.208637       1.765298       0.762238
# min             4.300000          2.000000       1.000000       0.100000
# 25%             5.100000          2.800000       1.600000       0.300000
# 50%             5.800000          3.000000       4.350000       1.300000
# 75%             6.400000          3.300000       5.100000       1.800000
# max             7.900000         42.000000       6.900000       2.500000
#
#        target
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
iris.nunique(axis=0)
# Out:
# sepal length (cm)    35
# sepal width (cm)     23
# petal l. / cm        43
# petal w. / cm        22
# target                0
# species               3
# dtype: int64

# %% [markdown]
# 4) Missing data (isnull) and duplicates (duplicated)

# %%
iris.duplicated().any() #this tells me if any duplicates are present in the data frame
# Out:
# np.True_

# %%
iris[iris.duplicated()==True] #this tells me that the iris data set has in row 142 a duplicate
# Out:
#      sepal length (cm)  sepal width (cm)  petal l. / cm  petal w. / cm  \
# 142                5.8               2.7            5.1            1.9
#
#      target    species
# 142     NaN  virginica

# %% [markdown]
# 5) Drop unnecessary columns and rename columns

# %%
iris.drop(columns=["target"], axis=1, inplace=True) #here we drop the target column since it has just NaN

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal l. / cm  petal w. / cm species
# 0                5.1               3.5            1.4            0.2  setosa
# 1                4.9               3.0            1.4            0.2  setosa
# 2                4.7               3.2            1.3            0.2  setosa
# 3                4.6               3.1            1.5            0.2  setosa
# 4                5.0               3.6            1.4            0.2  setosa

# %%
iris.rename(columns={"petal l. / cm":"petal length (cm)", "petal w. / cm":"petal width (cm)"}, inplace=True)

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris.iloc[33,1] = 4.2 #Go to row index 33 and column index 1, and assign the value 4.2
#iloc selects data by integer location only (not by labels).
print(iris.iloc[33,1])
# Out:
# 4.2

# %%
iris["sepal width (cm)"].nlargest(3)
# Out:
# 15    4.4
# 33    4.2
# 32    4.1
# Name: sepal width (cm), dtype: float64

# %%
iris.iloc[33]
# Out:
# sepal length (cm)       5.5
# sepal width (cm)        4.2
# petal length (cm)       1.4
# petal width (cm)        0.2
# species              setosa
# Name: 33, dtype: object

# %% [markdown]
# 6) Export cleaned dataset as "DSA_iris_cleaned.csv" into the same folder

# %%
iris.to_csv("DSA_iris_cleaned.csv", index=False)
